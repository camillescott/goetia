# %%
# %pylab inline
# %config InlineBackend.figure_format = 'retina'
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import pandas as pd
import seaborn as sns
from ficus import FigureManager
from IPython.display import FileLink

# %%
meta_cols = ['full', 'tip', 'island', 'trivial']
data = pd.read_csv('mmetsp/Bathycoccus_prasinos/Bat_pra.unode_meta.csv')
del data['unknown']

# %%
with FigureManager(filename='Bat_pra.n_unode_meta.png', ncols=2, figsize=(16,8), show=True) as (fig, ax_mat):
    data[meta_cols].plot(ax=ax_mat[0], title='Number of Unitig-Node Types', lw=4)
    ax_mat[0].set_xlabel('Read Number')
    
    data[meta_cols].divide(data['n_unodes'], axis=0).plot(ax=ax_mat[1], lw=4,
                                                          title='Proportion of Unitig-Node Types')
    ax_mat[1].set_xlabel('Read Number')
FileLink('Bat_pra.n_unode_meta.png')
# Out:
# /work/boink/work/Bat_pra.n_unode_meta.png

# %%
with FigureManager(filename='Bat_pra.n_tags.png', figsize=(12,12), show=True) as (fig, ax):
    data[['n_dnodes', 'n_unodes', 'n_tags']].plot(ax=ax, title='Number of Unitig-Node Tags', lw=4)
    ax.set_xlabel('Read Number')
